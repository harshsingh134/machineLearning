# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\ABC\\AppData\\Local\\Temp\\Rar$DIa5200.15444\\spam_ham_dataset.csv')
df.shape
# Out:
# (5171, 4)

# %%
df.shape
# Out:
# (5171, 4)

# %% [markdown]
# #data clering
# # eda
# # text preprossing
# # model building
# # evalution
# # imporvement
# # webiste
# # deploy

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5171 entries, 0 to 5170
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5171 non-null   int64
#  1   label       5171 non-null   object
#  2   text        5171 non-null   object
#  3   label_num   5171 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 161.7+ KB

# %%
df.drop(columns= ['Unnamed: 0','label_num'],inplace=True)

# %%
df.sample(5)
# Out:
#      label                                               text
# 3250   ham  Subject: hpl meter # 986240 el campo / shangha...
# 296   spam                                      Subject: \r\n
# 693    ham  Subject: oasis sept 01 production\r\nmike ,\r\...
# 4387   ham  Subject: meters\r\nafter talking to both vance...
# 698    ham  Subject: tenaska iv 1 / 01\r\nwe need to chang...

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
df['label'] = encoder.fit_transform(df['label'])

# %%
df.head()
# Out:
#    label                                               text
# 0      0  Subject: enron methanol ; meter # : 988291\r\n...
# 1      0  Subject: hpl nom for january 9 , 2001\r\n( see...
# 2      0  Subject: neon retreat\r\nho ho ho , we ' re ar...
# 3      1  Subject: photoshop , windows , office . cheap ...
# 4      0  Subject: re : indian springs\r\nthis deal is t...

# %%
# missing values
df.isnull().sum()
# Out:
# label    0
# text     0
# dtype: int64

# %%
# chek for duplicate values
df.duplicated().sum()
# Out:
# np.int64(178)

# %%
df = df.drop_duplicates(keep='first')

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (4993, 2)

# %% [markdown]
# 2 EDA

# %%
df.head()
# Out:
#    label                                               text
# 0      0  Subject: enron methanol ; meter # : 988291\r\n...
# 1      0  Subject: hpl nom for january 9 , 2001\r\n( see...
# 2      0  Subject: neon retreat\r\nho ho ho , we ' re ar...
# 3      1  Subject: photoshop , windows , office . cheap ...
# 4      0  Subject: re : indian springs\r\nthis deal is t...

# %%
df['label'].value_counts()
# Out:
# label
# 0    3531
# 1    1462
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.pie(df['label'].value_counts(), labels=['ham','spam'],autopct='%0.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x270a9908ec0>,
#   <matplotlib.patches.Wedge at 0x270a9924b90>],
#  [Text(-0.6664987851717366, 0.8750882066195381, 'ham'),
#   Text(0.6664990703116317, -0.8750879894466217, 'spam')],
#  [Text(-0.36354479191185624, 0.4773208399742935, '70.72%'),
#   Text(0.36354494744270816, -0.47732072151633903, '29.28%')])

# %%
# data is imbalanced

# %%
import nltk

# %%
df['num_characters'] = df['text'].apply(len)

# %%
df.head()
# Out:
#    label                                               text  num_characters
# 0      0  Subject: enron methanol ; meter # : 988291\r\n...             327
# 1      0  Subject: hpl nom for january 9 , 2001\r\n( see...              97
# 2      0  Subject: neon retreat\r\nho ho ho , we ' re ar...            2524
# 3      1  Subject: photoshop , windows , office . cheap ...             414
# 4      0  Subject: re : indian springs\r\nthis deal is t...             336

# %%
df['num_words'] = df['text'].apply(lambda x: len(str(x).split()))

# %%
text = "I am learning machine learning"
len(text.split())
# Out:
# 5
