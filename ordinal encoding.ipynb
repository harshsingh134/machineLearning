# %%
import numpy as np
import pandas as pd
df = pd.read_csv('C:\\Users\\ABC\\AppData\\Local\\Temp\\Rar$DIa7384.29013\\customers.csv')
df.sample(5)
# Out:
#            id             name    segment       state             city
# 424  EB-13975       Erica Bern  Corporate  California        Fairfield
# 361  RD-19585         Rob Dowd   Consumer    Kentucky        Henderson
# 130  BP-11185     Ben Peterman  Corporate    Colorado           Arvada
# 310  PG-18820  Patrick Gardner   Consumer  California    San Francisco
# 2    SO-20335   Sean O'Donnell   Consumer     Florida  Fort Lauderdale

# %%
df = df.iloc[:,1:]
df.head()
# Out:
#               name    segment           state             city
# 0      Claire Gute   Consumer        Kentucky        Henderson
# 1  Darrin Van Huff  Corporate      California      Los Angeles
# 2   Sean O'Donnell   Consumer         Florida  Fort Lauderdale
# 3  Brosina Hoffman   Consumer      California      Los Angeles
# 4     Andrew Allen   Consumer  North Carolina          Concord

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(df.iloc[:,:2],df.iloc[:,1],test_size=0.2)
from sklearn.preprocessing import OrdinalEncoder

# %%
x_train
# Out:
#                 name      segment
# 631       Brian Derr     Consumer
# 213   Darren Koutras     Consumer
# 707      Heather Jas  Home Office
# 442   Aaron Smayling    Corporate
# 277      Seth Vernon     Consumer
# ..               ...          ...
# 390  Penelope Sewall  Home Office
# 348      Greg Hansen     Consumer
# 98       Joseph Holt     Consumer
# 36   Julie Creighton    Corporate
# 632     Chris McAfee     Consumer
#
# [634 rows x 2 columns]

# %%
from sklearn.preprocessing import OrdinalEncoder
oe = OrdinalEncoder(categories=[['Low','Medium','High'],['Basic','Standard','Premium']])
# oe.fit(x_train)
x_train = oe.fit_transform(x_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 4
#       2 oe = OrdinalEncoder(categories=[['Low','Medium','High'],['Basic','Standard','Premium']])
#       3 # oe.fit(x_train)
# ----> 4 x_train = oe.fit_transform(x_train)
#
# File c:\Users\ABC\.anaconda\ankit\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# ...
