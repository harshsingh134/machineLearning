# %%
import numpy as np
data = np.array([[2,3,5],[6,8,9]])
data
# # zeros = np.zeros([1,2,3])
# zeros
# ones = np.ones([1]) 
# ones
# #
# hape = np.linspace(1,10,5)
# hape
# array bana
# Out:
# array([[2, 3, 5],
#        [6, 8, 9]])

# %%
# shape 
data.shape
a = np.array([1,2,3,4,5,6])
b = np.array([1,2,3,4,5,6])
# b = a.reshape(-1,1)
# b
# np.ndim(b)
# np.shape
# np.reshape(data)
np.size(b)
a.T
# Out:
# array([[1, 2],
#        [2, 5],
#        [3, 8],
#        [4, 9],
#        [5, 6],
#        [6, 7]])

# %%
# mathematical operation
np.mean(a)
np.sum(a)
np.std(a)
np.var(a)
np.min(a)
np.max(a)
np.median(a)
np.corrcoef(a)
np.cov(a)
# Out:
# array(3.5)

# %%
# lincar algebra
import numpy as np
a = np.array([1,2,3,4,5,6])
b = np.array([1,2,3,4,5,6])
# h = np.dot(a, b)
A = np.array([[1,2],[3,4]])
h = np.linalg.inv(A)
h
h = np.linalg.det(A)
h
h = np.linalg.eig(A)
h
# Out:
# EigResult(eigenvalues=array([-0.37228132,  5.37228132]), eigenvectors=array([[-0.82456484, -0.41597356],
#        [ 0.56576746, -0.90937671]]))

# %%
# data prepocessing
np.where(a>2;)
# Out:
#   Cell In[101], line 2
#     np.where(a>2;)
#                 ^
# SyntaxError: invalid syntax
