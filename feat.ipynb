# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('C:\\Users\\ABC\\AppData\\Local\\Temp\\Rar$DIa25084.41166\\Social_Network_Ads.csv')
df.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %% [markdown]
# Train test split

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
x = df.drop(['Purchased'], axis=1)
y = df['Purchased']
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=0
)

X_train.shape,X_test.shape
# X_test.shape
# Out:
# ((320, 2), (80, 2))

# %% [markdown]
# standardScaler

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)
scaler.mean_
# Out:
# array([3.8218750e+01, 6.9928125e+04])

# %%
X_train
# Out:
#      Age  EstimatedSalary
# 336   58           144000
# 64    59            83000
# 55    24            55000
# 106   26            35000
# 300   58            38000
# ..   ...              ...
# 323   48            30000
# 192   29            43000
# 117   36            52000
# 47    27            54000
# 172   26           118000
#
# [320 rows x 2 columns]

# %%
X_train_scaled
# Out:
# array([[ 1.92295008e+00,  2.14601566e+00],
#        [ 2.02016082e+00,  3.78719297e-01],
#        [-1.38221530e+00, -4.32498705e-01],
#        [-1.18779381e+00, -1.01194013e+00],
#        [ 1.92295008e+00, -9.25023920e-01],
#        [ 3.67578135e-01,  2.91803083e-01],
#        [ 1.73156642e-01,  1.46942725e-01],
#        [ 2.02016082e+00,  1.74040666e+00],
#        [ 7.56421121e-01, -8.38107706e-01],
#        [ 2.70367388e-01, -2.87638347e-01],
#        [ 3.67578135e-01, -1.71750061e-01],
#        [-1.18475597e-01,  2.20395980e+00],
#        [-1.47942605e+00, -6.35303205e-01],
#        [-1.28500455e+00, -1.06988428e+00],
#        [-1.38221530e+00,  4.07691369e-01],
#        [-1.09058306e+00,  7.55356227e-01],
#        [-1.47942605e+00, -2.00722133e-01],
#        [ 9.50842613e-01, -1.06988428e+00],
#        [ 9.50842613e-01,  5.81523798e-01],
#        [ 3.67578135e-01,  9.87132798e-01],
#        [ 5.61999628e-01, -8.96051849e-01],
#        [-6.04529329e-01,  1.45068594e+00],
# ...

# %%
X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_test_scaled = pd.DataFrame(X_test_scaled,columns =X_test_scaled.columns)
# np.round(X_train_scaled.describe(),1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 2
#       1 X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns)
# ----> 2 X_test_scaled = pd.DataFrame(X_test_scaled,columns =X_test_scaled.columns)
#       3 # np.round(X_train_scaled.describe(),1)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'

# %%
np.round(X_train_scaled.describe(),1)
# Out:
#          Age  EstimatedSalary
# count  320.0            320.0
# mean     0.0              0.0
# std      1.0              1.0
# min     -2.0             -1.6
# 25%     -0.8             -0.8
# 50%     -0.0             -0.0
# 75%      0.8              0.5
# max      2.1              2.3

# %% [markdown]
# Effect of Scaling

# %%
fig, (ax1,ax2) = plt.subplots(ncols=2, figsize=(12,5))
ax1.scatter(X_train['Age'], X_train['EstimatedSalary'])
ax1.set_title("Before Scaling")
ax2.scatter(X_train_scaled['Age'], X_train_scaled['EstimatedSalary'],color='red')
ax2.set_title('After Scaling')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))
ax1.set_title('Before Scaling')
sns.kdeplot(X_train['Age'], ax=ax1)
sns.kdeplot(X_train['EstimatedSalary'], ax=ax1)
# after scaling
ax2.set_title('After Standardization')
sns.kdeplot(X_train_scaled['Age'], ax=ax2)
sns.kdeplot(X_train_scaled['EstimatedSalary'], ax=ax2)
plt.show()

# %% [markdown]
# Comparison of Distributions

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))
ax1.set_title('Age DistributionBefore Scaling')
sns.kdeplot(X_train['Age'], ax=ax1)
# sns.kdeplot(X_train['EstimatedSalary'], ax=ax1)
# after scaling
ax2.set_title('Age Distribution After Standard scaling')
sns.kdeplot(X_train_scaled['Age'], ax=ax2)
# sns.kdeplot(X_train_scaled['EstimatedSalary'], ax=ax2)
plt.show()

# %%
df.describe()
# Out:
#               Age  EstimatedSalary   Purchased
# count  400.000000       400.000000  400.000000
# mean    37.655000     69742.500000    0.357500
# std     10.482877     34096.960282    0.479864
# min     18.000000     15000.000000    0.000000
# 25%     29.750000     43000.000000    0.000000
# 50%     37.000000     70000.000000    0.000000
# 75%     46.000000     88000.000000    1.000000
# max     60.000000    150000.000000    1.000000

# %% [markdown]
# Effect of outlier

# %%
df = df.append(pd.DataFrame({'Age':[5,90,95], 'EstimatedSalary':[10000,2000000,30000000], 'purchased':[0,1,1]}), ignore_index= True)
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13632\3148459066.py in ?()
# ----> 1 df = df.append(pd.DataFrame({'Age':[5,90,95], 'EstimatedSalary':[10000,2000000,30000000], 'purchased':[0,1,1]}), ignore_index= True)
#       2 df
#
# c:\Users\ABC\.anaconda\ankit\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
# df
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %%
plt.scatter(df['Age'], df['EstimatedSalary'])
