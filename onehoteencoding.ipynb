# %%
import numpy as np
import pandas as pd
df = pd.read_csv('C:\\Users\\ABC\\AppData\\Local\\Temp\\Rar$DIa16820.49299\\cars.csv')
df.head()
# Out:
#    Make      Model  Variant Ex-Showroom_Price Displacement  Cylinders  \
# 0  Tata  Nano Genx       Xt      Rs. 2,92,667       624 cc        2.0
# 1  Tata  Nano Genx       Xe      Rs. 2,36,447       624 cc        2.0
# 2  Tata  Nano Genx  Emax Xm      Rs. 2,96,661       624 cc        2.0
# 3  Tata  Nano Genx      Xta      Rs. 3,34,768       624 cc        2.0
# 4  Tata  Nano Genx       Xm      Rs. 2,72,223       624 cc        2.0
#
#    Valves_Per_Cylinder              Drivetrain Cylinder_Configuration  \
# 0                  2.0  RWD (Rear Wheel Drive)                In-line
# 1                  2.0  RWD (Rear Wheel Drive)                In-line
# 2                  2.0  RWD (Rear Wheel Drive)                In-line
# 3                  2.0  RWD (Rear Wheel Drive)                In-line
# 4                  2.0  RWD (Rear Wheel Drive)                In-line
#
#   Emission_Norm  ... Leather_Wrapped_Steering Automatic_Headlamps Engine_Type  \
# ...

# %%
#df['Model'].nunique() #value_counts()
df['Variant']. nunique() #value_counts()
# Out:
# 1064

# %% [markdown]
# OneHotEncodung

# %%
pd.get_dummies(df[['Model', 'Variant']])
# Out:
#       Model_3-Series  Model_458 Speciale  Model_458 Spider  Model_488 Gtb  \
# 0              False               False             False          False
# 1              False               False             False          False
# 2              False               False             False          False
# 3              False               False             False          False
# 4              False               False             False          False
# ...              ...                 ...               ...            ...
# 1271           False               False             False          False
# 1272           False               False             False          False
# 1273           False               False             False          False
# 1274           False               False             False          False
# 1275           False               False             False          False
#
#       Model_5-Series  Model_6-Series  Model_7-Series  Model_718  \
# ...

# %% [markdown]
# k-1 OneHotEncoding

# %%
pd.get_dummies(df, columns=['Model', 'Variant'], drop_first= True)
# Out:
#             Make Ex-Showroom_Price Displacement  Cylinders  \
# 0           Tata      Rs. 2,92,667       624 cc        2.0
# 1           Tata      Rs. 2,36,447       624 cc        2.0
# 2           Tata      Rs. 2,96,661       624 cc        2.0
# 3           Tata      Rs. 3,34,768       624 cc        2.0
# 4           Tata      Rs. 2,72,223       624 cc        2.0
# ...          ...               ...          ...        ...
# 1271       Honda     Rs. 13,02,000      1498 cc        4.0
# 1272       Honda     Rs. 14,21,000      1498 cc        4.0
# 1273       Honda     Rs. 14,31,000      1497 cc        4.0
# 1274       Honda     Rs. 12,01,000      1497 cc        4.0
# 1275  Mitsubishi     Rs. 68,62,560      3200 cc        4.0
#
#       Valves_Per_Cylinder               Drivetrain Cylinder_Configuration  \
# 0                     2.0   RWD (Rear Wheel Drive)                In-line
# 1                     2.0   RWD (Rear Wheel Drive)                In-line
# ...

# %% [markdown]
# OneHotencoding using sklearn

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df.iloc[:,0:4], df.iloc[:,-1], test_size=0.2, random_state=42)
x_train.head()
# Out:
#          Make          Model           Variant Ex-Showroom_Price
# 984       Kia         Seltos    Htx 1.5 Diesel     Rs. 14,14,000
# 415  Mahindra     Kuv100 Nxt  K2 6Str Cng Taxi      Rs. 5,42,913
# 780     Volvo            S60          Momentum     Rs. 38,50,500
# 919      Fiat  Linea Classic      1.3 Multijet      Rs. 7,51,203
# 96     Toyota     Etios Liva     Dual Tone Vxd      Rs. 7,56,700

# %%
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder()
x_train_new = ohe.fit_transform(x_train[['Model', 'Variant']]).toarray()
x_test_new = ohe.transform(x_test[['Model', 'Variant']]).toarray()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 4
#       2 ohe = OneHotEncoder()
#       3 x_train_new = ohe.fit_transform(x_train[['Model', 'Variant']]).toarray()
# ----> 4 x_test_new = ohe.transform(x_test[['Model', 'Variant']]).toarray()
#
# File c:\Users\ABC\.anaconda\ankit\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# ...
