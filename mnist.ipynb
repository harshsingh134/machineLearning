# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('c:\\Users\\ABC\\AppData\\Local\\Temp\\Rar$DRa6796.41463\\registered_companies.csv')
df.shape
# Out:
# C:\Users\ABC\AppData\Local\Temp\ipykernel_2496\77327579.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('c:\\Users\\ABC\\AppData\\Local\\Temp\\Rar$DRa6796.41463\\registered_companies.csv')
# (1992170, 17)

# %%
df.isnull()
df.isnull().sum()
df.dropna()
# Out:
#         CORPORATE_IDENTIFICATION_NUMBER  \
# 70                L01110GJ1991PLC015846
# 71                L01110GJ1994PLC021066
# 72                L01110GJ1994PLC021368
# 73                L01110GJ1996PLC029329
# 74                L01111GJ2011PLC068414
# ...                                 ...
# 1992152           U45500NL2016PTC013415
# 1992153           U50100NL2013PTC008357
# 1992155           U50101NL2012PTC008325
# 1992156           U50200NL2013PTC008356
# 1992169           U74990NL2016PTC008397
#
#                                        COMPANY_NAME COMPANY_STATUS  \
# 70                      AMRAWORLD AGRICO LIMITED              ACTV
# 71                    TRANS TECHNO FOODS LIMITED              ULQD
# 72                 GALAXY AGRICO EXPORTS LIMITED              ACTV
# 73                  CHEMCRUX ENTERPRISES LIMITED              ACTV
# 74                     JIYA ECO-PRODUCTS LIMITED              ACTV
# ...                                             ...            ...
# ...

# %%
pd.get_dummies(df["COMPANY_CATEGORY"])
# Out:
#          Company Limited by Guarantee  Company limited by Shares  \
# 70                              False                       True
# 71                              False                       True
# 72                              False                       True
# 73                              False                       True
# 74                              False                       True
# ...                               ...                        ...
# 1992152                         False                       True
# 1992153                         False                       True
# 1992155                         False                       True
# 1992156                         False                       True
# 1992169                         False                       True
#
#          Unlimited Company
# 70                   False
# 71                   False
# 72                   False
# 73                   False
# 74                   False
# ...

# %%
df['column'].astype('category')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\ABC\.anaconda\ankit\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'column'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df['column'].astype('category')
#
# ...
