# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
df = pd.read_csv('C:\\Users\\ABC\\AppData\\Local\\Temp\\Rar$DIa14924.47793\\SBIN.NS_stock_data.csv')
df.head()
df.info()
df.describe()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7124 entries, 0 to 7123
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  7124 non-null   object
#  1   open        7115 non-null   float64
#  2   high        7115 non-null   float64
#  3   low         7115 non-null   float64
#  4   close       7115 non-null   float64
#  5   adjclose    7115 non-null   float64
#  6   volume      7115 non-null   float64
#  7   ticker      7124 non-null   object
# dtypes: float64(6), object(2)
# memory usage: 445.4+ KB
# Unnamed: 0    0
# open          9
# high          9
# low           9
# close         9
# adjclose      9
# volume        9
# ticker        0
# dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
df = pd.read_csv('C:\\Users\\ABC\\AppData\\Local\\Temp\\Rar$DIa14924.47793\\SBIN.NS_stock_data.csv')
df.head(20)
# Out:
#     Unnamed: 0       open       high        low      close   adjclose  \
# 0   1996-01-01  18.691147  18.978922  18.540184  18.823240  12.409932
# 1   1996-01-02  18.894005  18.964767  17.738192  18.224106  12.014930
# 2   1996-01-03  18.327892  18.568489  17.643839  17.738192  11.694572
# 3   1996-01-04  17.502312  17.832542  17.223972  17.676863  11.654143
# 4   1996-01-05  17.738192  17.785366  17.459852  17.577793  11.588823
# 5   1996-01-08  17.478724  17.643839  16.922047  17.063574  11.249804
# 6   1996-01-09  16.889023  18.681711  16.705036  17.997660  11.865639
# 7   1996-01-10  17.407959  17.714603  17.054138  17.172079  11.321341
# 8   1996-01-11  16.983376  17.926895  16.983376  17.827826  11.753665
# 9   1996-01-12  17.879719  18.233540  17.573074  17.837261  11.759888
# 10  1996-01-15  18.021248  18.200518  17.785366  17.893871  11.797212
# 11  1996-01-16  17.903307  19.530882  17.785366  18.271280  12.046034
# ...

# %%
sns.countplot(df['high'])
# Out:
# <Axes: ylabel='count'>

# %%
df['low'].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
plt.hist(df['low'],bins=5)
# Out:
# (array([3534., 2702.,  354.,  468.,   57.]),
#  array([ 13.21400928, 170.35121231, 327.48841534, 484.62561836,
#         641.76282139, 798.90002441]),
#  <BarContainer object of 5 artists>)

# %%
sns.distplot(df['low'])
# Out:
# C:\Users\ABC\AppData\Local\Temp\ipykernel_11376\1036317385.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['low'])
# <Axes: xlabel='low', ylabel='Density'>

# %%
df.head()
# Out:
#    Unnamed: 0       open       high        low      close   adjclose  \
# 0  1996-01-01  18.691147  18.978922  18.540184  18.823240  12.409932
# 1  1996-01-02  18.894005  18.964767  17.738192  18.224106  12.014930
# 2  1996-01-03  18.327892  18.568489  17.643839  17.738192  11.694572
# 3  1996-01-04  17.502312  17.832542  17.223972  17.676863  11.654143
# 4  1996-01-05  17.738192  17.785366  17.459852  17.577793  11.588823
#
#        volume   ticker
# 0  43733533.0  SBIN.NS
# 1  56167280.0  SBIN.NS
# 2  68296318.0  SBIN.NS
# 3  86073880.0  SBIN.NS
# 4  76613039.0  SBIN.NS

# %%
sns.boxplot(df['low'])
# Out:
# <Axes: ylabel='low'>

# %%
sns.heatmap(pd.crosstab(df['low'],df['high']))
# Out:
# <Axes: xlabel='high', ylabel='low'>

# %%
df.groupby('low').mean(['high'])
# Out:
#                   open        high       close    adjclose      volume
# low
# 13.214009    14.341516   14.341516   13.346102    9.799649   6041265.0
# 13.478195    13.478195   13.959390   13.813145   10.142586   4403029.0
# 13.596135    14.091483   14.143377   13.822580    9.531410  43648002.0
# 13.747098    13.968826   14.190553   14.190553    9.785150  56808496.0
# 13.869756    14.247164   14.624573   13.935802   10.232648   2415749.0
# ...                ...         ...         ...         ...         ...
# 770.549988  790.000000  792.799988  773.700012  773.700012  16778340.0
# 772.900024  783.650024  790.299988  783.900024  783.900024  26710525.0
# 783.000000  790.000000  793.400024  788.049988  788.049988  15497868.0
# 798.700012  807.000000  831.250000  826.500000  826.500000  27297179.0
# 798.900024  815.900024  816.900024  801.299988  801.299988  14964358.0
#
# [5538 rows x 5 columns]

# %%
sns.clustermap(pd.crosstab(df['low'],df['high']))
# Out:
# c:\Users\ABC\.anaconda\ankit\Lib\site-packages\seaborn\matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)
# c:\Users\ABC\.anaconda\ankit\Lib\site-packages\seaborn\matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %%
sns.pairplot(df,hue='low')

# %%
sns.heatmap(df.pivot_table(values='high',index='low',columns='open'))
# Out:
# <Axes: xlabel='open', ylabel='low'>
